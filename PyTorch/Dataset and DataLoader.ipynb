# %% [markdown]
# #### `Dataset` and `DataLoader`: The Why?
# Loading entire datasets into memory at once can cause problems like memory overflow and slow processing. Dataset and DataLoader classes solve these issues by:
# 1. Loading data in smaller batches to prevent memory overflow
#
# 2. Using parallel processing to speed up computations.
#
#
# These tools help us work with large datasets more efficiently.

# %%
# Importing necessaey libraries
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

import torch
from torch.utils.data import Dataset, DataLoader

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Generate random data for 100 students
n_students = 1000

# Generate features
cgpa = np.random.uniform(5.0, 10.0, n_students)  # CGPA between 5.0 and 10.0
iq = np.random.normal(100, 15, n_students)  # IQ with mean 100 and std 15
marks_12th = np.random.uniform(60, 100, n_students)  # 12th marks between 60 and 100
marks_10th = np.random.uniform(60, 100, n_students)  # 10th marks between 60 and 100

# Generate placement status (binary)
# Higher probability of placement for students with better scores
placement_prob = (cgpa/10 * 0.3 + iq/150 * 0.3 + marks_12th/100 * 0.2 + marks_10th/100 * 0.2)
placed = np.random.binomial(1, placement_prob)

# Create DataFrame
student_data = pd.DataFrame({
    'CGPA': np.round(cgpa, 2),
    'IQ': np.round(iq),
    'Marks_12th': np.round(marks_12th, 2),
    'Marks_10th': np.round(marks_10th, 2),
    'Placed': placed
})

print("Sample of generated student data:")
student_data.head()
# Out:
# Sample of generated student data:
#    CGPA     IQ  Marks_12th  Marks_10th  Placed
# 0  6.87  103.0       98.86       75.51       0
# 1  9.75   80.0       73.25       92.14       1
# 2  8.66  106.0       79.28       96.07       1
# 3  7.99  109.0       67.84       68.14       0
# 4  5.78  108.0       84.43       62.68       1

# %%
# Shape of the dataset
student_data.shape
# Out:
# (1000, 5)

# %%
# Splitting the data
X = student_data.drop(columns=['Placed']),
y = student_data['Placed']

# %% [markdown]
# #### The Golden Rule: "Fit Once, Transform Anytime"
#
# Preprocessing generally falls into two categories:
#
# ##### 1. Global Preprocessing (Requires the whole dataset)
# **Examples:** Scaling (StandardScaler, MinMax), Vocabulary Building (NLP), Label Encoding, Imputing Missing Values (Mean/Median).
#
# *   **Where:** In `__init__` (or before passing data to the Dataset).
# *   **Why:** These techniques need to see *all* the data to calculate statistics (like Mean or Max). You cannot calculate the "mean of the dataset" by looking at just one row in `__getitem__`.
# *   **Best Practice:** Calculate these statistics *once* and apply them *once* (if data fits in memory).
#
# ##### 2. On-the-Fly Preprocessing (Per-item independent)
# **Examples:** Data Augmentation (Random flips/rotations), Resizing images, Convert to Tensor, Normalization (using *known* mean/std).
#
# *   **Where:** In `__getitem__`.
# *   **Why:** These are specific to the individual item.
#     *   **Augmentation:** You want a *different* random crop every time you load the image.
#     *   **Memory efficiency:** If you have 100GB of images, you can't load them all in `__init__`. You load and resize one specific image in `__getitem__` only when needed.
#
# ---
#
# #### Summary of Best Practices
#
# | Type of Data | Technique | Where to put it? |
# | :--- | :--- | :--- |
# | **Tabular** | Scaling (Standard/MinMax) | `__init__` (Calculate once, apply once) |
# | **Tabular** | Encoding / Missing Values | `__init__` |
# | **Images** | **Data Augmentation** | `__getitem__` (Needs to be random per epoch) |
# | **Images** | Resizing / Normalization | `__getitem__` (If loading images from disk to save RAM) |
# | **Text** | Vocabulary Building | `__init__` (Needs full corpus) |
# | **Text** | Tokenization / Padding | Can be both, but often `__getitem__` or `collate_fn` |

# %%
# Building a Dataset Class
class CustomDataset(Dataset):
    def __init__(self, features: np.array, labels: np.array) -> None:
        """ In this method, you write an operation which loads the data from any local/cloud storage """

        # Global Preprocessing Steps
        scaler = StandardScaler()
        self.features = scaler.fit_transform(X = features) # Applies feature by feature 
        
        # The data we are getting is directly provided by the user through features and labels
        self.features = torch.tensor(features, device='cpu', requires_grad=False)
        self.labels = torch.tensor(labels, device='cpu', requires_grad=False)

    def __len__(self) -> torch.int32: # len(df) -> 1000 rows
        """ Return the size of the dataset """
        return len(self.features)

    def __getitem__(self, index): # df[index] -> recode[index]
        """ Here you can mention the return data you want, however the way you have mentioned here simillarly you have to access it while loading the data for training """

        # Local Preprocessing Steps —→ Augumentation, Image resizing
        return self.features[index], self.labels[index]

# %%
# Creating an object of dataset class
dataset = CustomDataset(
    features=np.array(X[0]),
    labels=np.array(y)
)

# %%
# Finding the length of the dataset
len(dataset)
# Out:
# 1000

# %%
# Accessing a row
index = int(input("Enter the index: "))
print(f"Features at index {index}:", dataset[index][0])
print(f"Labels at index {index}:", dataset[index][1])
# Out:
# Features at index 10: tensor([  5.1000, 106.0000,  68.7600,  85.9300], dtype=torch.float64)
# Labels at index 10: tensor(1, dtype=torch.int32)

# %%
# Creating a DataLoader object
dataloader = DataLoader(
    dataset=dataset,
    batch_size=5,
    shuffle=True, # Will be False for data like Time Series
    pin_memory=True,
    num_workers=0 # If you mention more than zero workers then you will not be able to print the data
)

# Returning the generator
dataloader

# %%
for batch_features, batch_labels in dataloader: # At every iteration, dataloader return whatever you returned in __getitem__ function
    print(batch_features, batch_labels)
    print("-" * 50)
# Out:
# tensor([[  5.1000, 106.0000,  68.7600,  85.9300],
#         [  7.0500, 108.0000,  67.8100,  82.9600],
#         [  5.6400, 104.0000,  84.0600,  95.9200],
#         [  9.8200,  77.0000,  71.6200,  67.6200],
#         [  5.0700, 113.0000,  93.7100,  91.8400]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.0200, 137.0000,  75.8100,  61.9800],
#         [  8.1100, 111.0000,  67.0100,  93.3500],
#         [  7.6600,  95.0000,  87.3000,  90.5000],
#         [  5.3700,  90.0000,  88.9600,  67.5200],
#         [  7.4600, 125.0000,  69.0200,  92.7000]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.9100, 106.0000,  92.6900,  69.0400],
#         [  7.1600, 100.0000,  97.2700,  68.8000],
#         [  7.9300, 113.0000,  98.0900,  66.8400],
#         [  8.1000, 109.0000,  66.6300,  82.6600],
#         [  5.7800, 116.0000,  71.2300,  95.0900]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.6600, 132.0000,  72.1200,  92.2200],
#         [  5.1200, 134.0000,  87.1100,  61.4000],
#         [  9.0700, 114.0000,  99.7900,  99.2200],
#         [  8.0900,  89.0000,  93.8800,  77.7100],
#         [  7.2500,  88.0000,  67.5400,  73.2800]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.6300,  97.0000,  86.7400,  88.6600],
#         [  9.2700,  85.0000,  93.3700,  65.1900],
#         [  9.7000,  85.0000,  64.8400,  83.8900],
#         [  8.4900, 102.0000,  98.4300,  83.0700],
#         [  6.1200,  96.0000,  89.5500,  96.6900]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.4200, 111.0000,  72.1600,  73.0100],
#         [  5.3200, 127.0000,  89.1700,  87.7900],
#         [  7.1900,  99.0000,  70.8600,  69.1900],
#         [  5.7400,  92.0000,  98.0200,  74.9400],
#         [  5.8300, 114.0000,  88.0900,  76.4900]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.6800, 109.0000,  84.8300,  67.1700],
#         [  6.8200, 123.0000,  86.1900,  77.1400],
#         [  6.6800,  89.0000,  77.3800,  86.5500],
#         [  5.9500,  94.0000,  96.8300,  65.3800],
#         [  5.9100,  79.0000,  83.6500,  82.2800]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.3600,  99.0000,  66.4500,  84.5500],
#         [  9.8500, 119.0000,  94.2600,  60.4500],
#         [  5.6700,  91.0000,  96.7400,  79.0200],
#         [  8.3400,  87.0000,  79.8500,  75.9100],
#         [  6.9200,  76.0000,  77.1600,  75.8400]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.6200, 139.0000,  92.2800,  61.5800],
#         [  9.4800,  94.0000,  68.7200,  99.9100],
#         [  5.4100,  98.0000,  80.0000,  70.0400],
#         [  8.6500,  91.0000,  76.8800,  70.8800],
#         [  9.9300, 105.0000,  69.1300,  63.6900]], dtype=torch.float64) tensor([1, 1, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.3500,  96.0000,  71.9200,  69.5300],
#         [  7.1400, 103.0000,  77.2400,  70.3800],
#         [  6.8700, 103.0000,  98.8600,  75.5100],
#         [  8.9700,  76.0000,  98.8300,  71.5800],
#         [  6.8800, 114.0000,  97.7100,  69.8700]], dtype=torch.float64) tensor([0, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.2500, 109.0000,  64.3700,  84.9100],
#         [  9.8200, 109.0000,  89.5100,  69.3000],
#         [  6.7300, 113.0000,  87.0400,  93.8800],
#         [  5.3600, 125.0000,  78.8900,  80.3900],
#         [  8.0900, 101.0000,  79.2400,  75.2400]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.5600,  88.0000,  74.6300,  96.1700],
#         [  7.7100, 117.0000,  79.0600,  99.5800],
#         [  7.2900,  98.0000,  77.3100,  83.8800],
#         [  6.4700, 100.0000,  65.0200,  72.7000],
#         [  7.2100,  89.0000,  73.9200,  88.2500]], dtype=torch.float64) tensor([0, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.6000,  86.0000,  69.6800,  80.0100],
#         [  8.4200,  80.0000,  86.2900,  96.4200],
#         [  6.8400,  89.0000,  60.0600,  70.8800],
#         [  7.5500, 132.0000,  98.5600,  82.6500],
#         [  8.8500, 111.0000,  82.4300,  62.4600]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.9100,  86.0000,  93.1400,  87.7400],
#         [  7.8800,  93.0000,  95.6300,  89.2100],
#         [  8.1700, 121.0000,  73.6200,  62.6900],
#         [  7.4600,  90.0000,  88.9100,  68.4300],
#         [  6.4000,  90.0000,  71.9800,  70.7400]], dtype=torch.float64) tensor([0, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5
 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.1200,  93.0000,  74.3500,  64.0400],
#         [  7.5800, 115.0000,  82.1000,  82.7100],
#         [  6.3700, 100.0000,  66.5100,  84.5600],
#         [  5.2900, 101.0000,  90.9300,  60.4100],
#         [  9.4600, 118.0000,  96.5500,  94.9100]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.3600, 110.0000,  62.8700,  63.8000],
#         [  5.4900, 113.0000,  72.3700,  83.3500],
#         [  5.1900, 107.0000,  84.1400,  79.5800],
#         [  8.9900, 100.0000,  62.0100,  62.2800],
#         [  6.3700, 108.0000,  69.6600,  74.5900]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.3300,  84.0000,  74.7400,  85.9900],
#         [  9.7400, 103.0000,  76.4400,  90.9100],
#         [  7.2000, 116.0000,  98.2000,  90.0700],
#         [  9.9300, 107.0000,  82.1500,  73.6800],
#         [  6.6100, 104.0000,  80.8100,  83.1700]], dtype=torch.float64) tensor([0, 1, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.9300, 107.0000,  82.7800,  83.9700],
#         [  6.4700,  85.0000,  67.7500,  65.0200],
#         [  7.6900, 112.0000,  83.3500,  66.4100],
#         [  6.0300,  95.0000,  74.8400,  73.7100],
#         [  7.9600, 109.0000,  96.5800,  81.9300]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.9500,  93.0000,  76.3000,  79.3800],
#         [  8.5000, 119.0000,  91.3300,  93.3800],
#         [  8.9200,  73.0000,  61.5600,  82.0300],
#         [  9.1100, 108.0000,  70.3800,  89.5500],
#         [  7.6600, 111.0000,  62.0700,  63.8100]], dtype=torch.float64) tensor([1, 1, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 8.5300, 87.0000, 75.9200, 74.9000],
#         [ 6.9900, 86.0000, 87.4100, 72.2300],
#         [ 8.7500, 85.0000, 73.4900, 87.1000],
#         [ 8.7300, 91.0000, 61.7000, 76.7300],
#         [ 9.7100, 99.0000, 66.4000, 90.5700]], dtype=torch.float64) tensor([1, 0, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.5900,  85.0000,  89.9400,  77.0600],
#         [  8.8000,  92.0000,  66.2900,  73.3800],
#         [  6.5900, 115.0000,  95.2100,  80.0500],
#         [  5.4300,  93.0000,  97.3100,  86.4700],
#         [  9.5100, 121.0000,  76.5500,  75.4900]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.6300, 127.0000,  82.9400,  99.8900],
#         [  7.5200, 105.0000,  98.6400,  96.8300],
#         [  8.9900,  97.0000,  71.8900,  71.7600],
#         [  6.7100, 103.0000,  73.0700,  89.2100],
#         [  6.5500, 111.0000,  98.0600,  64.7500]], dtype=torch.float64) tensor([1, 1, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.2600, 111.0000,  64.2100,  78.6500],
#         [  5.5800, 107.0000,  72.5300,  67.0000],
#         [  5.4100, 102.0000,  61.5000,  93.7900],
#         [  9.2600, 118.0000,  61.8000,  64.7500],
#         [  8.6100, 103.0000,  65.3800,  78.7600]], dtype=torch.float64) tensor([1, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.9900, 106.0000,  99.1400,  83.3300],
#         [  9.7000, 109.0000,  61.9300,  90.4200],
#         [  5.4300, 113.0000,  84.9900,  73.1300],
#         [  9.4700,  88.0000,  76.7600,  86.1700],
#         [  8.9700, 120.0000,  60.7600,  63.4000]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6
], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.9700,  90.0000,  90.2900,  77.2500],
#         [  6.2100, 100.0000,  98.8100,  77.0400],
#         [  6.4600, 100.0000,  75.8800,  74.0200],
#         [  8.6900,  84.0000,  60.1500,  65.7200],
#         [  5.6800,  99.0000,  95.3000,  62.3400]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.2700, 108.0000,  80.0200,  66.5800],
#         [  9.6000, 114.0000,  77.3400,  61.1100],
#         [  5.5400,  90.0000,  73.0100,  97.8700],
#         [  9.3400,  88.0000,  73.8100,  87.6400],
#         [  5.7600, 100.0000,  76.9100,  73.2100]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.8100,  80.0000,  99.2500,  62.6900],
#         [  6.5200, 104.0000,  84.3200,  90.6600],
#         [  7.2000, 107.0000,  78.1700,  91.1900],
#         [  8.5300, 121.0000,  60.4700,  91.8500],
#         [  9.5000, 113.0000,  64.9900,  79.5400]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.9800, 113.0000,  84.6700,  60.6500],
#         [  7.8100,  89.0000,  91.9400,  87.9600],
#         [  6.8500, 132.0000,  99.9100,  77.5900],
#         [  5.9300, 102.0000,  72.4500,  73.0700],
#         [  8.4700, 100.0000,  60.6000,  65.0400]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.3900, 111.0000,  81.7200,  66.7900],
#         [  9.6500, 116.0000,  85.8300,  69.9600],
#         [  6.6100,  79.0000,  82.1100,  90.1000],
#         [  5.4700,  74.0000,  97.1700,  94.4900],
#         [  7.5100,  90.0000,  88.2800,  92.9000]], dtype=torch.float64) tensor([0, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.2000, 126.0000,  68.1900,  95.1700],
#         [  8.8500,  82.0000,  75.3700,  70.8600],
#         [  9.5700, 104.0000,  80.0200,  78.3800],
#         [  9.8500,  80.0000,  78.2500,  96.3300],
#         [  5.8900, 106.0000,  71.1500,  65.8900]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.5000,  89.0000,  95.5400,  83.4800],
#         [  9.7500,  89.0000,  81.8600,  86.3500],
#         [  6.5900, 100.0000,  99.5200,  69.6600],
#         [  5.5700,  86.0000,  64.7400,  92.9400],
#         [  7.0600, 104.0000,  62.3200,  75.1900]], dtype=torch.float64) tensor([0, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.9800,  96.0000,  65.7200,  79.5800],
#         [  9.9000, 109.0000,  90.3500,  87.0300],
#         [  5.0500,  83.0000,  68.1300,  84.2700],
#         [  7.8200, 131.0000,  70.7500,  96.7400],
#         [  6.7400, 123.0000,  86.9100,  82.8800]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.4700, 110.0000,  77.5700,  63.4400],
#         [  9.8100,  84.0000,  74.7900,  93.1000],
#         [  6.9700, 110.0000,  80.4200,  92.6800],
#         [  8.4800, 134.0000,  86.0700,  66.4300],
#         [  5.7400, 128.0000,  92.2000,  70.8800]], dtype=torch.float64) tensor([0, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.0000,  84.0000,  85.2100,  64.7300],
#         [  9.5400,  96.0000,  84.4000,  87.0600],
#         [  6.8500, 106.0000,  79.3600,  83.8100],
#         [  5.7000,  92.0000,  84.6800,  62.7500],
#         [  5.6800, 107.0000,  82.5600,  88.5900]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.6800, 115.0000,  85.7900,  69.5000],
#         [  7.5900, 109.0000,  90.2500,  90.4900],
#         [  6.2200, 108.0000,  67.4300,  99.8200],
#         [  9.0000, 119.0000,  86.2100,  67.0800],
#         [  5.8100,  85.0000,  83.5500,  61.2700]], dtype=torch.float64) tensor([1, 1, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.7500,  80.0000,  72.4700,  86.7100],
#         [  9.8800, 106.0000,  92.1600,  67.0200],
#         [  8.8100,  90.0000,  98.9700,  63.1600],
#         [  7.9900, 128.0000,  69.3700,  72.6300],
#         [  8.4700, 125.0000,  79.4000,  73.5200]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.3700,  97.0000,  94.2000,  89.2600],
#         [  7.6300, 113.0000,  89.3000,  70.0900],
#         [  8.4500,  89.0000,  95.0400,  92.9800],
#         [  6.9000,  96.0000,  80.2300,  67.4700],
#         [  8.8600,  88.0000,  71.8000,  87.6900]], dtype=torch.float64) tensor([1, 1, 1, 0, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.9200,  96.0000,  75.3500,  90.0000],
#         [  9.5700, 104.0000,  62.5000,  87.9100],
#         [  9.2800,  94.0000,  95.2700,  92.5000],
#         [  9.9600,  82.0000,  60.3100,  89.4000],
#         [  9.3200, 103.0000,  64.9200,  72.9800]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.1400, 130.0000,  77.0100,  81.6100],
#         [  6.2700,  77.0000,  65.2700,  79.7000],
#         [  8.3300,  89.0000,  62.7300,  71.8900],
#         [  9.6000, 103.0000,  90.6200,  75.1600],
#         [  9.9800, 121.0000,  60.3600,  92.8300]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.3200, 118.0000,  62.0000,  75.9800],
#         [  8.6300, 106.0000,  92.9000,  98.0600],
#         [  7.4600, 102.0000,  71.3000,  86.3300],
#         [  8.1700,  90.0000,  91.7700,  76.0800],
#         [  9.7500,  80.0000,  73.2500,  92.1400]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.8500, 111.0000,  64.1000,  60.6600],
#         [  5.6000,  84.0000,  83.6300,  97.5400],
#         [  7.8000, 106.0000,  69.9400,  60.0000],
#         [  9.6900, 112.0000,  96.2400,  74.4400],
#         [  8.9400,  57.0000,  88.1800,  77.1000]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.5700,  93.0000,  88.2200,  61.5600],
#         [  5.8100, 108.0000,  61.0200,  93.7900],
#         [  7.0900, 112.0000,  76.6300,  87.0300],
#         [  9.3900,  75.0000,  72.6300,  77.9600],
#         [  6.8000,  81.0000,  85.9100,  79.7000]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.3900, 106.0000,  91.7300,  93.0600],
#         [  5.1300, 111.0000,  71.3700,  74.8900],
#         [  8.7500,  87.0000,  89.5200,  72.9400],
#         [  7.2500,  91.0000,  72.8700,  68.3600],
#         [  6.4600, 101.0000,  64.5500,  74.7800]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.5400, 110.0000,  74.9800,  72.9200],
#         [  5.9300, 119.0000,  96.8400,  69.2600],
#         [  6.8700, 109.0000,  97.4500,  81.6100],
#         [  6.0300, 120.0000,  90.8400,  87.1000],
#         [  9.4900, 115.0000,  62.7400,  82.2600]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.1400, 109.0000,  95.6000,  96.0400],
#         [  5.5400, 118.0000,  83.2900,  95.1700],
#         [  9.5000, 112.0000,  62.3100,  96.4500],
#         [  8.1600,  92.0000,  97.0600,  97.5200],
#         [  8.8800,  99.0000,  80.6300,  75.6800]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.9400,  96.0000,  98.2700,  79.4900],
#         [  8.5400,  75.0000,  60.3100,  62.6600],
#         [  8.5100,  76.0000,  97.9100,  80.2200],
#         [  7.2400, 114.0000,  88.5000,  76.0100],
#         [  7.5100,  86.0000,  85.2900,  74.4200]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.1500, 108.0000,  81.1900,  83.8400],
#         [  5.2000, 105.0000,  95.6700,  68.8200],
#         [  6.2600,  64.0000,  70.0400,  86.9500],
#         [  5.6400,  86.0000,  76.7800,  93.0900],
#         [  8.7100, 100.0000,  62.0700,  62.2700]], dtype=torch.float64) tensor([0, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.5400, 116.0000,  87.5400,  86.6700],
#         [  5.7100,  81.0000,  85.8600,  73.6000],
#         [  6.3800,  85.0000,  76.6600,  70.0500],
#         [  9.3200, 107.0000,  90.8700,  83.1100],
#         [  9.6300,  94.0000,  93.5900,  97.1500]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.9000, 115.0000,  66.4700,  73.9000],
#         [  7.0000, 108.0000,  70.8400,  84.1300],
#         [  7.3000, 100.0000,  80.6700,  76.5300],
#         [  7.5700,  93.0000,  88.0900,  60.3300],
#         [  7.0600, 103.0000,  94.8600,  66.4500]], dtype=torch.float64) tensor([0, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.0500, 108.0000,  69.0500,  72.3400],
#         [  7.4800, 121.0000,  60.0600,  80.7200],
#         [  7.7800, 108.0000,  74.2800,  79.0900],
#         [  6.6000, 102.0000,  87.1000,  98.4600],
#         [  8.2100, 114.0000,  64.2100,  96.3400]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.3200, 103.0000,  67.1700,  63.3400],
#         [  7.3100,  77.0000,  83.9100,  87.3000],
#         [  6.3300, 110.0000,  62.5000,  73.4100],
#         [  5.6400,  93.0000,  91.2100,  61.6800],
#         [  5.2200,  70.0000,  88.3100,  77.2000]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.2000, 127.0000,  97.6300,  97.3700],
#         [  8.4500, 105.0000,  84.9400,  85.4400],
#         [  9.7500,  91.0000,  90.9600,  97.3300],
#         [  9.6100,  88.0000,  87.2000,  62.4000],
#         [  5.7000, 117.0000,  66.6100,  61.6600]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.8900,  95.0000,  76.2000,  72.5600],
#         [  8.5700, 120.0000,  89.6800,  89.1300],
#         [  5.6500,  97.0000,  93.9200,  63.3900],
#         [  8.6300,  93.0000,  97.7600,  71.0800],
#         [  9.9400, 104.0000,  80.8600,  70.3900]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.4800,  87.0000,  60.4000,  98.1800],
#         [  7.3100,  79.0000,  89.1700,  60.2600],
#         [  5.4300, 105.0000,  91.2300,  76.6900],
#         [  6.5600, 124.0000,  84.1500,  66.8000],
#         [  9.4600, 106.0000,  62.4900,  93.2400]], dtype=torch.float64) tensor([1, 1, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.9200, 116.0000,  82.8800,  99.8900],
#         [  7.3400,  87.0000,  85.6200,  78.3200],
#         [  6.4400,  98.0000,  88.1900,  68.9700],
#         [  5.4900, 116.0000,  79.5100,  66.2000],
#         [  9.2200,  90.0000,  68.6300,  62.0100]], dtype=torch.float64) tensor([0, 0, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.7700, 109.0000,  69.8700,  74.9800],
#         [  5.4200, 106.0000,  94.5400,  62.0800],
#         [  9.9800, 119.0000,  81.7700,  85.3500],
#         [  8.6100,  96.0000,  86.5700,  83.3100],
#         [  5.5800, 109.0000,  61.7500,  85.4500]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.7800,  97.0000,  88.2200,  88.4900],
#         [  7.3600, 130.0000,  71.0200,  91.1200],
#         [  9.3800, 105.0000,  71.5000,  82.2500],
#         [  5.1000,  68.0000,  90.5800,  72.6000],
#         [  5.7800,  96.0000,  60.8800,  63.4000]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.3600, 106.0000,  81.5300,  93.2600],
#         [  6.9400,  99.0000,  87.1500,  70.8400],
#         [  9.9300, 101.0000,  62.3100,  77.8700],
#         [  9.5200,  79.0000,  64.0700,  86.4700],
#         [  6.7300, 124.0000,  63.6600,  63.6000]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.9500,  85.0000,  60.4000,  91.0100],
#         [  7.5600,  81.0000,  79.5600,  87.8900],
#         [  7.8700, 105.0000,  90.9200,  70.6200],
#         [  8.8200, 108.0000,  87.0800,  64.3200],
#         [  6.7300, 102.0000,  88.5600,  62.7800]], dtype=torch.float64) tensor([1, 1, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.0900,  80.0000,  79.4200,  60.9000],
#         [  9.4700,  82.0000,  89.5200,  76.4500],
#         [  8.3000, 122.0000,  98.5600,  91.1600],
#         [  6.8000,  89.0000,  78.0500,  66.5100],
#         [  7.5200, 100.0000,  66.0600,  89.2600]], dtype=torch.float64) tensor([1, 1, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.0400, 101.0000,  89.9500,  67.4100],
#         [  9.1100, 101.0000,  74.3100,  89.6700],
#         [  6.7500, 114.0000,  86.2700,  76.7100],
#         [  5.2300, 115.0000,  97.6700,  78.9600],
#         [  7.9200, 105.0000,  91.5700,  88.0200]], dtype=torch.float64) tensor([0, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.1200, 104.0000,  96.7000,  70.8700],
#         [  9.9500, 111.0000,  74.7100,  66.9400],
#         [  5.2300,  87.0000,  65.2600,  86.4700],
#         [  8.9800, 114.0000,  74.1200,  67.7400],
#         [  5.5600, 111.0000,  73.4200,  61.1500]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.4800, 108.0000,  93.9400,  73.8300],
#         [  8.3100, 122.0000,  62.3800,  89.6900],
#         [  7.8000, 122.0000,  74.8700,  87.3500],
#         [  5.1100,  96.0000,  86.9500,  83.4200],
#         [  6.2600,  85.0000,  98.2400,  84.9800]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6
 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.0800,  83.0000,  88.1500,  66.0800],
#         [  7.7300,  94.0000,  64.5800,  95.6200],
#         [  5.8500,  97.0000,  97.8800,  83.5300],
#         [  9.5900,  91.0000,  94.2000,  68.3500],
#         [  7.9500, 105.0000,  85.6200,  74.8600]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.6700,  94.0000,  94.5100,  94.8300],
#         [  8.5200, 102.0000,  91.5000,  98.8500],
#         [  9.8700, 103.0000,  94.1500,  92.0400],
#         [  8.3300,  95.0000,  98.3900,  90.6600],
#         [  9.6600, 100.0000,  99.2500,  66.9000]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.9300,  81.0000,  64.2400,  71.0400],
#         [  9.2800, 136.0000,  77.3500,  68.7300],
#         [  9.1100, 104.0000,  78.3200,  67.4300],
#         [  9.3400, 107.0000,  63.0700,  63.2900],
#         [  7.6400, 118.0000,  65.8900,  64.8000]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.2500, 105.0000,  80.4500,  67.3100],
#         [  8.6900, 105.0000,  67.9700,  84.0400],
#         [  8.1700, 110.0000,  62.3100,  83.7300],
#         [  9.1900, 108.0000,  69.8900,  87.6800],
#         [  9.2500,  84.0000,  85.3700,  92.2300]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.5000, 113.0000,  62.8200,  94.9400],
#         [  6.2100, 104.0000,  67.2600,  70.6400],
#         [  6.9600, 123.0000,  87.4200,  86.9000],
#         [  8.0600,  84.0000,  89.6400,  91.9100],
#         [  6.9300, 100.0000,  74.7500,  75.9100]], dtype=torch.float64) tensor([1, 0, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.3800,  76.0000,  87.5500,  97.6200],
#         [  9.0400, 118.0000,  85.4800,  83.0700],
#         [  5.1700,  91.0000,  68.2100,  97.3800],
#         [  9.9200,  67.0000,  88.7500,  87.5700],
#         [  5.2300, 101.0000,  91.7000,  71.8500]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[ 7.5900, 99.0000, 62.6400, 82.5400],
#         [ 5.7200, 78.0000, 81.6600, 97.1300],
#         [ 6.5200, 99.0000, 80.5100, 82.3600],
#         [ 7.6800, 98.0000, 67.8800, 78.5600],
#         [ 8.4000, 83.0000, 81.7800, 68.9100]], dtype=torch.float64) tensor([0, 0, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.0100, 101.0000,  84.8500,  85.6600],
#         [  6.8800, 128.0000,  74.9600,  92.9700],
#         [  5.1800,  86.0000,  83.3800,  63.7800],
#         [  7.4700, 108.0000,  71.7300,  98.5300],
#         [  6.6400,  85.0000,  74.1200,  62.8000]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.7800, 127.0000,  88.8900,  87.9900],
#         [  7.7800, 124.0000,  90.6400,  92.3600],
#         [  7.8400, 114.0000,  77.5700,  78.6000],
#         [  7.6000,  92.0000,  87.4600,  67.8000],
#         [  9.2600, 106.0000,  90.1400,  86.9600]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.3900,  97.0000,  73.9500,  92.1500],
#         [  9.7000, 108.0000,  68.4300,  98.9200],
#         [  7.9900,  99.0000,  90.0500,  95.5700],
#         [  5.2700, 100.0000,  70.3500,  71.8400],
#         [  5.8600,  92.0000,  80.6000,  72.3100]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7
 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.3000, 104.0000,  87.7400,  81.2500],
#         [  8.8800,  86.0000,  74.7600,  90.3500],
#         [  9.3400, 105.0000,  94.3500,  83.4200],
#         [  8.2300,  95.0000,  92.1800,  66.7000],
#         [  9.0900,  90.0000,  96.3800,  84.3900]], dtype=torch.float64) tensor([1, 0, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.1300, 100.0000,  74.1500,  83.1400],
#         [  9.0400,  78.0000,  88.5600,  62.6600],
#         [  8.3400,  90.0000,  68.2800,  98.3200],
#         [  9.6400, 107.0000,  93.1400,  91.9300],
#         [  6.0600,  81.0000,  73.5500,  92.1500]], dtype=torch.float64) tensor([1, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.7000,  93.0000,  67.1700,  94.6400],
#         [  5.8500,  93.0000,  75.7800,  60.2100],
#         [  6.0200,  95.0000,  71.5700,  86.9000],
#         [  5.8000, 109.0000,  78.4700,  65.4200],
#         [  7.6200,  72.0000,  91.3500,  69.2000]], dtype=torch.float64) tensor([0, 1, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.7500, 106.0000,  63.6800,  68.4100],
#         [  5.9800, 126.0000,  87.7000,  69.1700],
#         [  9.3500,  65.0000,  63.7100,  85.2600],
#         [  9.0300, 118.0000,  80.9000,  93.7700],
#         [  8.1000, 108.0000,  64.5300,  78.7100]], dtype=torch.float64) tensor([0, 0, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.7700,  98.0000,  98.3100,  80.0600],
#         [  9.0500, 106.0000,  71.9800,  79.5100],
#         [  8.9500,  94.0000,  70.6200,  71.1000],
#         [  8.0600, 114.0000,  63.4800,  74.9000],
#         [  5.2600,  94.0000,  80.1900,  78.0000]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.9800,  85.0000,  74.1900,  66.2600],
#         [  8.7400,  90.0000,  62.1900,  79.3600],
#         [  8.3600,  98.0000,  64.2200,  63.8000],
#         [  8.6500, 104.0000,  87.7000,  70.5900],
#         [  9.6500,  96.0000,  93.4200,  65.0200]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.5900,  63.0000,  65.4600,  93.5700],
#         [  6.1300, 122.0000,  76.0700,  85.9500],
#         [  7.4800, 124.0000,  91.7100,  86.3900],
#         [  9.5300, 108.0000,  98.5400,  73.8000],
#         [  8.2900, 121.0000,  94.1600,  98.9400]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.1400, 103.0000,  87.5300,  76.4500],
#         [  6.4300,  93.0000,  69.0400,  95.5800],
#         [  6.7100, 110.0000,  75.8100,  78.2100],
#         [  8.5600,  85.0000,  93.1000,  71.4600],
#         [  9.3700,  95.0000,  65.1100,  77.2500]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.9300,  95.0000,  94.9700,  86.2700],
#         [  5.1400,  85.0000,  62.2500,  84.2900],
#         [  6.3000, 104.0000,  74.1800,  84.7700],
#         [  5.6900, 107.0000,  68.0500,  88.2100],
#         [  8.1900, 105.0000,  77.2000,  86.4800]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.8400, 100.0000,  97.0500,  74.0300],
#         [  6.1900,  81.0000,  97.3200,  69.3500],
#         [  8.1200, 113.0000,  64.1000,  77.7200],
#         [  8.6500, 109.0000,  93.3100,  70.7300],
#         [  8.0200,  97.0000,  76.4800,  64.8200]], dtype=torch.float64) tensor([1, 0, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.1000,  91.0000,  72.6500,  74.7000],
#         [  8.7900, 103.0000,  70.8200,  93.8000],
#         [  9.5300,  78.0000,  62.0900,  66.8300],
#         [  9.8500, 113.0000,  95.6100,  73.6800],
#         [  7.6500,  99.0000,  81.3400,  93.5300]], dtype=torch.float64) tensor([1, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.2100,  93.0000,  71.5100,  75.6800],
#         [  5.9300,  90.0000,  73.8900,  74.9200],
#         [  5.4600,  80.0000,  67.3400,  89.3700],
#         [  5.7000, 110.0000,  72.2700,  87.8900],
#         [  9.6800,  82.0000,  93.8400,  65.8800]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.4400, 133.0000,  88.9400,  66.0600],
#         [  9.7500,  83.0000,  77.4800,  61.3000],
#         [  6.7900,  99.0000,  71.4300,  76.4500],
#         [  7.5100, 101.0000,  68.0100,  83.7400],
#         [  9.5300,  93.0000,  71.1100,  66.2500]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.4800, 101.0000,  69.6800,  77.3500],
#         [  5.4500, 128.0000,  70.8100,  78.1900],
#         [  5.9200,  84.0000,  98.9200,  80.5600],
#         [  5.0200, 121.0000,  60.3600,  62.0200],
#         [  7.7100,  89.0000,  98.6000,  99.1700]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.7500,  61.0000,  71.3000,  84.4700],
#         [  6.2400, 125.0000,  75.9000,  94.0200],
#         [  7.9800, 138.0000,  72.3900,  75.7800],
#         [  7.8700,  97.0000,  81.9500,  61.3900],
#         [  9.5500,  95.0000,  62.0500,  86.8500]], dtype=torch.float64) tensor([0, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.8100, 111.0000,  93.3500,  99.8300],
#         [  6.1100, 117.0000,  79.6400,  75.5500],
#         [  6.5800, 110.0000,  90.7600,  62.5000],
#         [  9.7200,  80.0000,  69.1500,  74.5000],
#         [  6.0600, 100.0000,  70.0400,  82.4900]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.5100,  79.0000,  70.9900,  96.1000],
# ...
#         [  9.0800, 118.0000,  65.6900,  86.3800],
#         [  6.1600, 120.0000,  97.0800,  69.6100]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.2000, 128.0000,  73.6200,  83.8700],
#         [  9.9300,  95.0000,  69.6800,  64.1800],
#         [  8.3200,  59.0000,  87.6800,  99.9100],
#         [  8.2900, 124.0000,  98.0300,  71.6600],
#         [  6.3500,  97.0000,  91.0100,  85.7900]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.7500, 105.0000,  99.0900,  98.7900],
#         [  8.8100,  85.0000,  70.7400,  92.9300],
#         [  9.9500, 114.0000,  92.0000,  68.4500],
#         [  5.3300,  88.0000,  86.9600,  87.1900],
#         [  9.5500,  72.0000,  82.7800,  83.7900]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.1300,  99.0000,  96.3200,  97.5300],
#         [  6.2300, 101.0000,  94.8200,  83.3800],
#         [  7.9500, 103.0000,  91.6600,  75.6700],
#         [  6.6200, 104.0000,  60.9300,  84.9500],
#         [  5.7000, 116.0000,  76.2800,  72.1000]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.6400,  87.0000,  75.7300,  64.8200],
#         [  8.0300, 101.0000,  70.1200,  61.8000],
#         [  5.1800,  83.0000,  96.2400,  81.5200],
#         [  8.6600,  90.0000,  75.6700,  74.1900],
#         [  9.1500,  94.0000,  92.5700,  73.0800]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.8200, 122.0000,  73.3600,  70.3900],
#         [  6.7800, 104.0000,  64.6200,  62.4800],
#         [  6.7800, 110.0000,  80.5500,  86.4700],
#         [  7.7700, 106.0000,  77.9100,  71.5200],
#         [  7.7000,  95.0000,  69.6800,  65.0400]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.0400, 106.0000,  74.2800,  65.1300],
#         [  9.4900,  99.0000,  75.0100,  76.9300],
#         [  6.6700,  90.0000,  83.5800,  95.6200],
#         [  8.6300,  68.0000,  83.7400,  86.3500],
#         [  9.7700, 101.0000,  89.1500,  78.6700]], dtype=torch.float64) tensor([0, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.1400,  83.0000,  83.7500,  72.5500],
#         [  9.0100, 137.0000,  94.9500,  80.2800],
#         [  8.3000, 131.0000,  88.2800,  97.0800],
#         [  5.0700, 115.0000,  80.6000,  65.3300],
#         [  7.0500,  80.0000,  75.7100,  84.6800]], dtype=torch.float64) tensor([0, 0, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.0300,  90.0000,  81.3600,  92.8700],
#         [  8.3200, 113.0000,  75.4600,  95.3200],
#         [  8.4200,  88.0000,  88.4700,  68.5900],
#         [  5.5300, 101.0000,  85.1400,  92.5500],
#         [  6.1200,  90.0000,  76.3000,  89.5000]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.0400,  95.0000,  71.7000,  82.6300],
#         [  7.7300, 102.0000,  78.3100,  99.9800],
#         [  5.4600,  85.0000,  80.7600,  61.2000],
#         [  7.7700,  96.0000,  74.1700,  85.6400],
#         [  8.7800,  94.0000,  83.0800,  66.4500]], dtype=torch.float64) tensor([1, 1, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.6300,  94.0000,  93.8200,  83.8100],
#         [  8.7200,  93.0000,  70.5700,  68.0600],
#         [  9.1800, 111.0000,  85.1800,  65.6500],
#         [  8.6400,  92.0000,  72.0900,  85.9800],
#         [  8.8000,  79.0000,  77.8600,  63.5400]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.0800,  94.0000,  77.9700,  94.3900],
#         [  9.3300, 110.0000,  88.0500,  91.4900],
#         [  8.0700, 106.0000,  62.9200,  81.2900],
#         [  8.1800,  92.0000,  84.0400,  82.2900],
#         [  8.1000, 103.0000,  74.2800,  86.2600]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.4500, 112.0000,  66.1800,  93.0200],
#         [  9.6800, 110.0000,  68.2500,  78.0700],
#         [  6.6200, 118.0000,  93.5600,  74.9900],
#         [  5.0500,  97.0000,  78.5600,  69.3800],
#         [  8.8500,  77.0000,  80.1200,  74.4600]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.1700,  98.0000,  69.1800,  85.5100],
#         [  7.9600, 119.0000,  99.7100,  68.7100],
#         [  5.7700, 112.0000,  97.8700,  77.1600],
#         [  6.4700,  96.0000,  89.6200,  70.2600],
#         [  5.5100, 123.0000,  90.4700,  95.2400]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.1600, 113.0000,  67.7800,  88.6000],
#         [  7.9000,  94.0000,  89.3100,  91.6900],
#         [  5.3800, 100.0000,  95.7000,  66.2700],
#         [  6.0500,  90.0000,  80.8600,  86.6000],
#         [  9.4800, 123.0000,  70.0000,  72.6100]], dtype=torch.float64) tensor([0, 0, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.1400,  99.0000,  77.1500,  93.6400],
#         [  5.4900, 116.0000,  98.5600,  70.5300],
#         [  8.0300, 103.0000,  74.7700,  66.5200],
#         [  6.6900,  57.0000,  71.2400,  86.6900],
#         [  9.4500,  71.0000,  86.4400,  67.2500]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.8400,  81.0000,  70.3700,  92.1800],
#         [  5.5100, 113.0000,  60.9400,  70.4400],
#         [  9.0300, 113.0000,  71.5000,  71.2400],
#         [  7.6800,  99.0000,  73.7000,  62.1300],
#         [  7.4600, 117.0000,  63.5700,  60.0300]], dtype=torch.float64) tensor([1, 0, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.8800, 131.0000,  87.5100,  62.8400],
#         [  7.7500, 115.0000,  61.8700,  93.0300],
#         [  7.7500, 101.0000,  80.7200,  88.6400],
#         [  6.6900, 124.0000,  75.5200,  60.5800],
#         [  9.1500, 109.0000,  68.8900,  67.6000]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.7400,  98.0000,  78.9500,  98.7200],
#         [  9.3600,  99.0000,  95.3200,  69.3300],
#         [  7.1400, 101.0000,  65.6200,  65.2000],
#         [  9.7300, 139.0000,  85.9700,  60.5200],
#         [  7.6000, 123.0000,  99.7300,  97.3000]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.4100, 132.0000,  72.1200,  97.1500],
#         [  8.2500,  91.0000,  68.0200,  95.8900],
#         [  9.8100,  90.0000,  75.5300,  95.8200],
#         [  6.4300, 101.0000,  70.4000,  72.5600],
#         [  5.8900, 100.0000,  70.4100,  99.4900]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.4200, 101.0000,  92.9500,  91.2800],
#         [  5.6200, 115.0000,  82.8700,  65.9700],
#         [  6.7900,  92.0000,  83.0900,  97.5600],
#         [  9.3100,  91.0000,  94.6700,  92.5900],
#         [  8.8600, 109.0000,  96.7800,  72.1300]], dtype=torch.float64) tensor([1, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.9700, 131.0000,  63.1400,  84.9100],
#         [  5.2300,  89.0000,  66.6800,  74.0500],
#         [  7.3400,  92.0000,  65.6300,  62.2200],
#         [  6.4100,  95.0000,  71.8100,  77.5300],
#         [  9.0700, 115.0000,  84.3100,  82.0500]], dtype=torch.float64) tensor([0, 0, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.6000,  82.0000,  75.9100,  78.3600],
#         [  5.0800, 126.0000,  87.0700,  71.1300],
#         [  6.9800, 108.0000,  61.4400,  76.1300],
#         [  9.8500,  97.0000,  79.0800,  62.0100],
#         [  8.4600,  69.0000,  94.6200,  95.4400]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  6.6100, 116.0000,  99.3900,  86.3800],
#         [  6.5600, 127.0000,  73.8600,  82.5700],
#         [  6.1500, 114.0000,  83.9600,  90.6100],
#         [  5.4400, 123.0000,  63.2100,  85.3000],
#         [  8.9000, 111.0000,  99.2400,  83.7100]], dtype=torch.float64) tensor([1, 1, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.2600,  85.0000,  66.3800,  77.7600],
#         [  6.1900, 104.0000,  77.6200,  99.2400],
#         [  7.3700, 118.0000,  87.4800,  94.8300],
#         [  7.4100,  93.0000,  98.6800,  97.2200],
#         [  5.5200,  91.0000,  76.3900,  63.8700]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.2900, 120.0000,  80.1100,  75.2000],
#         [  8.5200,  99.0000,  96.4000,  94.9600],
#         [  9.9100,  74.0000,  73.8100,  75.7200],
#         [  8.0300, 100.0000,  71.4300,  63.3800],
#         [  8.9800,  94.0000,  71.8100,  89.0000]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.0300,  97.0000,  80.4500,  86.3600],
#         [  5.9100, 115.0000,  77.1000,  74.2600],
#         [  8.7700,  83.0000,  60.7700,  82.6300],
#         [  6.1900,  92.0000,  66.4200,  81.2700],
#         [  5.5200, 103.0000,  64.9700,  97.1700]], dtype=torch.float64) tensor([0, 0, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.2300,  84.0000,  87.8600,  78.1700],
#         [  9.7400,  92.0000,  94.6400,  83.0100],
#         [  5.6100,  92.0000,  92.8500,  92.1200],
#         [  6.8700,  82.0000,  86.9700,  96.3700],
#         [  5.5900, 111.0000,  66.6300,  83.3300]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.1300, 100.0000,  72.7500,  61.3500],
#         [  6.8700, 110.0000,  69.8600,  66.5100],
#         [  5.2900, 113.0000,  68.2800,  75.5800],
#         [  6.7300,  76.0000,  67.4500,  69.2600],
#         [  8.9500,  97.0000,  88.3700,  72.2900]], dtype=torch.float64) tensor([0, 0, 1, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.2900,  75.0000,  60.5900,  90.9100],
#         [  9.0100,  97.0000,  88.9400,  98.6100],
#         [  7.1400, 101.0000,  71.7800,  73.0500],
#         [  8.7300,  91.0000,  92.4400,  76.1000],
#         [  9.0600, 100.0000,  79.9600,  74.3700]], dtype=torch.float64) tensor([0, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.8300, 117.0000,  83.5000,  89.8800],
#         [  8.2300, 107.0000,  90.3600,  64.0100],
#         [  9.1300,  76.0000,  76.1700,  60.7700],
#         [  8.0600,  80.0000,  97.7900,  69.0500],
#         [  6.7700, 102.0000,  93.7500,  73.0700]], dtype=torch.float64) tensor([1, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.5400,  92.0000,  75.4200,  69.1600],
#         [  5.2800, 109.0000,  84.9000,  60.2800],
#         [  7.5100, 106.0000,  71.5400,  77.6900],
#         [  6.4900, 108.0000,  64.6900,  80.2400],
#         [  6.0600,  95.0000,  90.1700,  87.5200]], dtype=torch.float64) tensor([1, 1, 0, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.4000, 104.0000,  70.9600,  62.0200],
#         [  8.2300,  99.0000,  99.7500,  71.0100],
#         [  6.7500,  72.0000,  95.0800,  82.9000],
#         [  9.1600, 104.0000,  64.3200,  75.0200],
#         [  5.3700, 107.0000,  79.4400,  70.5600]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.0500,  74.0000,  75.8600,  62.0500],
#         [  6.2500, 128.0000,  66.6700,  95.9200],
#         [  5.1800,  77.0000,  93.0700,  99.6300],
#         [  8.2200, 121.0000,  80.0200,  77.2000],
#         [  8.1400, 105.0000,  62.7000,  86.3800]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  5.6000,  97.0000,  72.2500,  90.4300],
#         [  5.5700, 120.0000,  61.5800,  86.7100],
#         [  6.7900,  70.0000,  86.5000,  92.3400],
#         [  9.5300, 139.0000,  63.0200,  83.1200],
#         [  9.3100, 118.0000,  77.7000,  70.1800]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.5700,  88.0000,  91.5600,  67.5100],
#         [  9.6700, 103.0000,  75.9600,  79.1400],
#         [  6.4200, 118.0000,  84.1200,  83.2400],
#         [  7.7600, 102.0000,  82.1300,  94.0000],
#         [  6.9600,  62.0000,  67.6600,  84.5100]], dtype=torch.float64) tensor([0, 0, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.0000,  90.0000,  71.3000,  93.3200],
#         [  9.0500,  91.0000,  80.9000,  70.9500],
#         [  5.4600, 102.0000,  60.7000,  71.2600],
#         [  7.3100, 118.0000,  97.7800,  75.8800],
#         [  7.4500,  67.0000,  66.1700,  97.1700]], dtype=torch.float64) tensor([1, 1, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.2800,  93.0000,  80.3000,  88.9100],
#         [  5.9100,  84.0000,  92.1000,  77.3400],
#         [  7.9500, 104.0000,  65.5700,  66.6900],
#         [  5.0900,  68.0000,  94.0100,  80.4200],
#         [  7.0000, 131.0000,  77.3600,  66.9900]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.0000,  97.0000,  68.7800,  62.2800],
#         [  6.7800,  97.0000,  74.4100,  82.2700],
#         [  5.7800, 114.0000,  60.0100,  68.7500],
#         [  6.3400,  93.0000,  95.0500,  71.3800],
#         [  5.6000, 104.0000,  61.2400,  69.2800]], dtype=torch.float64) tensor([1, 0, 0, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.0000, 101.0000,  93.7300,  76.0600],
#         [  5.2300,  98.0000,  92.2800,  73.7600],
#         [  8.5200, 103.0000,  78.3400,  61.5600],
#         [  8.8800, 100.0000,  95.8100,  64.1400],
#         [  7.9200, 103.0000,  63.0500,  81.8700]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.5300, 114.0000,  79.7100,  62.6500],
#         [  8.2100, 112.0000,  79.3400,  74.2000],
#         [  9.4900,  64.0000,  65.9500,  96.8500],
#         [  8.6600, 106.0000,  79.2800,  96.0700],
#         [  6.8800, 114.0000,  97.7500,  92.7500]], dtype=torch.float64) tensor([1, 1, 1, 1, 0], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  8.1200,  77.0000,  82.3500,  70.7800],
#         [  5.2300, 102.0000,  91.5600,  86.9100],
#         [  7.2700, 121.0000,  86.6600,  76.0800],
#         [  7.2000,  85.0000,  62.2600,  86.9200],
#         [  9.1500, 131.0000,  70.0200,  90.4100]], dtype=torch.float64) tensor([1, 0, 0, 0, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  9.3900,  98.0000,  77.3100,  69.6200],
#         [  9.8500, 103.0000,  61.4700,  62.9600],
#         [  6.6400, 108.0000,  60.6800,  93.9200],
#         [  5.1400,  95.0000,  98.0400,  76.3100],
#         [  6.4100, 121.0000,  88.5300,  88.9800]], dtype=torch.float64) tensor([1, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
# tensor([[  7.8500, 107.0000,  79.3200,  87.5600],
#         [  5.8800, 100.0000,  84.6500,  88.0800],
#         [  9.8600, 103.0000,  96.0000,  84.7800],
#         [  6.1100, 103.0000,  61.5600,  86.1700],
#         [  5.7000, 104.0000,  84.5000,  96.3100]], dtype=torch.float64) tensor([0, 1, 1, 1, 1], dtype=torch.int32)
# --------------------------------------------------
